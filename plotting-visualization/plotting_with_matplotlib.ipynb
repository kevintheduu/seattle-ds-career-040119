# %% [markdown]
# # Data Visualization: Plotting with Matplotlib

# %% [markdown]
# ## Objectives
#
# 1. Configure a Jupyter Notebook for inline visualizations with `pyplot`
# 2. Create `fig` and `ax` objects with `plt.subplots()`
# 3. Add titles and axis labels to a plot.
# 4. Visualize data using a scatterplot.
# 5. Visualize sequential data using a line plot.
# 6. Visualize data using a bar chart.
# 7. Explain why data scientists don't use pie charts.
# 8. Use `pd.scatter_matrix()` for rapid data exploration.

# %% [markdown]
# ### 1. Configure Jupyter for inline visualizations with `pyplot`

# %%
import numpy as np
import pandas as pd
from scipy import stats
from matplotlib import pyplot as plt
# %matplotlib inline 
#show the plot in the same window, not a separate one

# %% [markdown]
# ### 2. Create `fig` and `ax` objects with `plt.subplots()`

# %% [markdown]
# #### 2a. Creating a figure with _one_ set of axes

# %%
fig, ax = plt.subplots()

#INconsistent, if you have multi subplots, comes back as an array of axis

# %%
# this returns an empty figure

# %%
# Apply a style
plt.style.use('ggplot')  # ggplot is the plotting library in R
fig, ax = plt.subplots()

# %%
ax.scatter(0.5, 0.5) #resets the limits if not explicitly defined

# %%
fig

# %% [markdown]
# #### 2(b) Creating a figure with _multiple_ axes

# %%
fig, axs = plt.subplots(2, 2)

# %%
# Fix the ugliness
fig.tight_layout() #unsquishes the sub-plots
fig

# %%
# Referencing one set of axes
ax = axs[0][0]
ax.scatter(0.5, 0.5, color='blue')
fig

# %%
# This does the same thing, for the remaining axes
axs[0][1].scatter(0.5, 0.5, color='purple')
axs[1][0].scatter(0.5, 0.5, color='red')
axs[1][1].scatter(0.5, 0.5, color='green')

# %%
fig

# %% [markdown]
# ### 3. Add titles and axis labels to a plot

# %%
fig, ax = plt.subplots()

# %%
# Label the plot
ax.set_title('Data Science Learning')
fig

# %%
# Label your axes
ax.set_xlabel('Week')
ax.set_ylabel('Mastery (%)')
fig

# %%
# Set limits
ax.set_xlim(1, 15)
ax.set_ylim(0, 100)
ax.set_yticks(range(0,100,10))
ax.set_xticks(range(0,15,1))
fig

# %% [markdown]
# #### 4. Visualize data using a scatterplot.

# %%
fig, ax = plt.subplots(figsize=(5, 5))

# Label plot
ax.set_title('Interesting Data')

# Set limits
ax.set_xlim(0, 5)
ax.set_ylim(0, 5)

# Generate data
exponential_distribution = stats.expon()
x = exponential_distribution.rvs(10000)
y = exponential_distribution.rvs(10000)


# Plot
ax.scatter(x, y, alpha=.1, color="purple")

# %% [markdown]
# ##### What's wrong with the plot above? How is it fixed below?

# %%
# Set figure size
fig, ax = plt.subplots(figsize=(5, 5))

# Label plot
ax.set_title('Interesting Data')

# Set limits
ax.set_xlim(0, 4)
ax.set_ylim(0, 4)

# Generate data
exponential_distribution = stats.expon()
x = exponential_distribution.rvs(10000)
y = exponential_distribution.rvs(10000)

# Plot with alpha transparency
ax.scatter(x, y, alpha=.05, color="purple")

# %% [markdown]
# #### 5. Visualize sequential data using a line plot.

# %%
fig, ax = plt.subplots()

# Label plot
ax.set_title('Data Science Learning')

# Label axes
ax.set_xlabel('Week')
ax.set_ylabel('Mastery (%)')

# Set limits
ax.set_xlim(1, 15)
ax.set_ylim(0, 100)

x = np.arange(0, 16)
y = 40 + x**2/4

ax.plot(x, y, linestyle="dashed", color="green")

# %% [markdown]
# #### 6. Visualize data using a bar chart.

# %%
fig, ax = plt.subplots(figsize=(7,4))

# Label plot
ax.set_title('Student\'s Favorite After-School Activities')

# Label axes
ax.set_xlabel('Activity')
ax.set_ylabel('Number of Students')

# Set limits
ax.set_ylim(0,100)
ax.set_xlim(-1,7)

x = ['Play Sports','Talk on Phone','Visit with Friends','Earn Money','Chat Online','School Clubs','Watch TV']
y = [45,53,99,44,66,22,37]
plt.xticks(rotation=45)
ax.bar(x, y)
# Out:
# <BarContainer object of 7 artists>

# %%
fig, ax = plt.subplots()

activity = ['Play Sports','Talk on Phone','Visit with Friends','Earn Money','Chat Online','School Clubs','Watch TV']
#y_pos = np.arange(len(activity))
number_of_students = [45,53,99,44,66,22,37]
ax.barh(activity, number_of_students)
ax.set_yticks(y_pos)
ax.set_yticklabels(activity,color= 'black')
#ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Number of Students',color='blue')
ax.set_title('Student\'s Favorite After-School Activities',color='Green')

plt.show()

# %%
ax.barh?

# %% [markdown]
# #### 7. Explain why data scientists don't use pie charts.

# %% [markdown]
# #### 8. Use `pd.scatter_matrix()` for rapid data exploration.
